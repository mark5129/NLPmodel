# %% [markdown]
# # XLSX to CSV converter
#
# The data for the project is recieved in the format of an excel file containing all the proffesional media articles as well as the regional articles. We want to convert each of these articles to csv files that can be loaded to the various models
#
# **Format in xlsx**
#
# Every row represents a text with various columns representing some information
#
# id | date | title | outlet | link | full text
#
# this has to be converted to an csv file with the same format

# %%
import pandas as pd

# %%
# make code that converts an xlsx file to csv. the xlsx file contains two sheets. each sheet represents one area of articles first sheet being "Professional media" and the other being "Regional Media". 
# The xlsx file is named "EnergyIslands_Pro+LocalMediaCoverage_Clean.xlsx" and the csv files should be named "pro_media.csv" and "reg_media.csv" respectively. 
# The csv files should be saved in the same directory as the xlsx file and should have the same rows and columns as the respective sheet.

# read the xlsx file
xlsx = pd.ExcelFile("raw_data/EnergyIslands_Pro_LocalMediaCoverage_Clean.xlsx")


# read the first sheet
pro_media = pd.read_excel(xlsx, "Professional media")

# read the second sheet
reg_media = pd.read_excel(xlsx, "Regional media (Emil)")

# save the first sheet as a csv file
#pro_media.to_csv("raw_data/pro_media.csv", index=False)

# save the second sheet as a csv file
#reg_media.to_csv("raw_data/reg_media.csv", index=False)

print("Done!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       1 # make code that converts an xlsx file to csv. the xlsx file contains two sheets. each sheet represents one area of articles first sheet being "Professional media" and the other being "Regional Media".
#       2 # The xlsx file is named "EnergyIslands_Pro+LocalMediaCoverage_Clean.xlsx" and the csv files should be named "pro_media.csv" and "reg_media.csv" respectively.
#       3 # The csv files should be saved in the same directory as the xlsx file and should have the same rows and columns as the respective sheet.
#       4
#       5 # read the xlsx file
# ----> 6 xlsx = pd.ExcelFile("raw_data/EnergyIslands_Pro_LocalMediaCoverage_Clean.xlsx")
#       9 # read the first sheet
#      10 pro_media = pd.read_excel(xlsx, "Professional media")
#
# File ~/Desktop/Bachelor projekt/NLPmodel/.venv/lib/python3.11/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/Desktop/Bachelor projekt/NLPmodel/.venv/lib/python3.11/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/Desktop/Bachelor projekt/NLPmodel/.venv/lib/python3.11/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'raw_data/EnergyIslands_Pro_LocalMediaCoverage_Clean.xlsx'
