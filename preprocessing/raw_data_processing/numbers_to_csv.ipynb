# %% [markdown]
# ## Convert from xlsx to csv for sci media

# %%
import pandas as pd

# Example usage
numbers_file_path = 'raw_data/EnergyIslands_ScopusAbstracts.xlsx'
csv_file_path = 'raw_data/EnergyIslands_ScopusAbstracts.csv'

# read the xlsx file
xlsx = pd.ExcelFile(numbers_file_path)

# Read the .numbers file
df = pd.read_excel(xlsx)

# Write the dataframe to a .csv file
df.to_csv(csv_file_path, index=False)

print(f"File converted successfully and saved as {csv_file_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 8
#       5 csv_file_path = 'raw_data/EnergyIslands_ScopusAbstracts.csv'
#       7 # read the xlsx file
# ----> 8 xlsx = pd.ExcelFile(numbers_file_path)
#      10 # Read the .numbers file
#      11 df = pd.read_excel(xlsx)
#
# File ~/Desktop/Bachelor projekt/NLPmodel/.venv/lib/python3.11/site-packages/pandas/io/excel/_base.py:1554, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
# -> 1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
# ...

# %%
df = pd.read_csv(csv_file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(csv_file_path)
#
# File ~/Desktop/Bachelor projekt/NLPmodel/.venv/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
print(df.columns)
